# %%
import json
import pickle
import gzip
import re
from collections import defaultdict, Counter
import pymorphy3
import requests
from bs4 import BeautifulSoup
import time
import json
import os
from urllib.parse import urljoin
from abc import ABC, abstractmethod
from functools import wraps
import logging
import unittest

# %%
def setup_logging():
    log_format = '%(asctime)s - [%(levelname)s] - %(name)s - %(message)s'
    
    logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(message)s',
    handlers=[
        logging.FileHandler('stichi_log.log', encoding='utf-8')
    ]
)

# %%
setup_logging()

# %%
logger = logging.getLogger(__name__)

# %%
def log_processing(func):
    @wraps(func)
    def wrapper(self, *args, **kwargs):
        logger = logging.getLogger(self.__class__.__module__ + '.' + self.__class__.__name__)
        
        poem = None
        for arg in args:
            if hasattr(arg, 'title'):
                poem = arg
                break
        
        title = poem.title if poem else "Неизвестно"
        logger.info(f"Начата обработка: {title}")
        start_time = time.time()
        
        try:
            result = func(self, *args, **kwargs)
            elapsed = time.time() - start_time
            logger.info(f"Успешно завершено: {title} за {elapsed:.2f}с")
            return result
        except Exception as e:
            logger.error(f"Ошибка при обработке {title}: {e}", exc_info=True)
            raise
    return wrapper

# %%
class PoemAnalysisError(Exception):
    def __init__(self, message):
        logger.error(f"PoemAnalysisError: {message}")
        super().__init__(message)

class EmptyPoemError(PoemAnalysisError): #пустое стихотворение
    pass

class DataFetchError(PoemAnalysisError): #ошибка загрузки данных
    pass

# %%
class DataFetchError(PoemAnalysisError):
    def __init__(self, message):
        logger = logging.getLogger(__name__)
        logger.error(f"DataFetchError: {message}")
        super().__init__(message)

# %%
class Poem:
    def __init__(self, title, lines, url=""):
        self.title = title
        self.lines = lines
        self.url = url
        self.meter = None
        self.rhyme_scheme = None

    def __str__(self):
        return f"{self.title} ({len(self.lines)} строк)"

    def __len__(self):
        return len(self.lines)

    def is_empty(self):
        return len([l for l in self.lines if l.strip()]) == 0

    @property
    def text(self):
        return "\n".join(self.lines)

# %%
class VerseProcessor(ABC):

    def __init__(self, language="ru"):
        self.language = language

    @abstractmethod
    def process(self, poem): #обработка стихотворения
        pass

    def validate_input(self, poem): # проверка данных
        if not poem or poem.is_empty():
            raise EmptyPoemError("Стихотворение пустое")
        return True

# %%
class MetricalAnalyzer(VerseProcessor):

    def __init__(self):
        super().__init__("ru")
        self.morph = pymorphy3.MorphAnalyzer(lang='ru')
        self.meters = {
            'ямб': [0, 1],
            'хорей': [1, 0],
            'дактиль': [1, 0, 0],
            'амфибрахий': [0, 1, 0],
            'анапест': [0, 0, 1]
        }
        logger.debug(f"Инициализирован MetricalAnalyzer")

    @log_processing
    def process(self, poem): #метр
        logger.debug(f"Начинаем анализ метра для {poem.title}")
        self.validate_input(poem)

        meter_scores = defaultdict(int)
        total_lines = 0

        for line in poem.lines:
            if line.strip():
                total_lines += 1
                line_meter = self._analyze_line(line)
                if line_meter:
                    meter_scores[line_meter] += 1
                    logger.debug(f"Строка: {line_meter}")

        #основной метр
        if meter_scores and total_lines > 0:
            dominant = max(meter_scores, key=meter_scores.get)
            confidence = meter_scores[dominant] / total_lines
            poem.meter = dominant if confidence > 0.7 else "смешанный"
            logger.info(f"Результат анализа {poem.title}: {poem.meter}, уверенность: {confidence:.2%}")
            return {"meter": poem.meter, "confidence": confidence}
        else:
            poem.meter = "неопределен"
            logger.warning(f"Метр не определён для {poem.title}")
            return {"meter": "неопределен", "confidence": 0.0}



    def _analyze_line(self, line):
        logger.debug(f"Анализ строки: '{line[:50]}...'")
        bitstring = self._line_to_bitstring(line) #битовая строка ударений

        if not bitstring:
            logger.debug("Пустая битовая строка")
            return None

        #сравнение с эталонами
        scores = {}
        for meter_name, meter_pattern in self.meters.items():
            score = self._compare_with_meter(bitstring, meter_pattern)
            scores[meter_name] = score

        best_meter = max(scores, key=scores.get)
        return best_meter if scores[best_meter] > 0.5 else None

    def _line_to_bitstring(self, line):
        bitstring = []
        i = 0
        vowels = "аеёиоуыэюя"
        while i < len(line):
            char = line[i]
            if char in "`'~": #исключение для ударения
                i += 1
                continue
                
            #обработка ударений
            if char.lower() in vowels:
                if i + 1 < len(line) and line[i + 1] in "`'~":
                    bitstring.append('1')
                    i += 2
                else:
                    bitstring.append('0')
                    i += 1
            else:
                i += 1
        return ''.join(bitstring)

    def _compare_with_meter(self, bitstring, meter_pattern):
        if not bitstring:
            return 0.0

        pattern_length = len(meter_pattern)
        meter_bitstring = ''.join(str(meter_pattern[i % pattern_length])
                                  for i in range(len(bitstring)))

        #индекс жаккара
        matches = sum(1 for a, b in zip(bitstring, meter_bitstring) if a == '1' and b == '1')
        total_emphasised = sum(1 for b in bitstring if b == '1')

        if total_emphasised == 0:
            return 0.0
        return matches / total_emphasised

# %%
class DataCollector:

    def __init__(self, base_url="https://rvb.ru/pushkin/"):
        self.base_url = base_url
        self.session = requests.Session()
        self.logger = logging.getLogger(f"{__name__}.DataCollector")
        self.logger.info(f"Инициализация DataCollector с base_url={base_url}")

    def fetch_poem(self, url):
        try:
            response = self.session.get(url, timeout=10)
            response.encoding = "windows-1251"

            soup = BeautifulSoup(response.text, "html5lib")
            title = self._extract_title(soup)
            lines = self._extract_lines(soup)

            return Poem(title=title, lines=lines, url=url)

        except requests.RequestException as e:
            self.logger.error(f"Ошибка загрузки {url}: {e}", exc_info=True)
            raise DataFetchError(f"Ошибка загрузки {url}: {e}")

    def _extract_title(self, soup):
        h1 = soup.find("h1")
        return h1.get_text(strip=True) if h1 else "Без заголовка"

    def _extract_lines(self, soup):
        lines = []
        for stanza in soup.find_all("p", class_=["stanza", "continuation"]):
            for span in stanza.find_all("span", class_=["line", "line2r"]):
                lines.append(span.get_text(strip=True))
            lines.append("")  #пустая строка между строфами

        return lines[:-1] if lines and lines[-1] == "" else lines

# %%
class PoemCollection:
    #перегрузка
    def __init__(self):
        self.poems = []
        self._index_by_title = {}

    def add_poem(self, poem):
        if not poem.is_empty():
            self.poems.append(poem)
            self._index_by_title[poem.title] = poem
            return True
        else:
            print(f"Пустое: {poem.title}")
            return False
            
    def __len__(self):
        return len(self.poems)

    def __getitem__(self, idx):
        if isinstance(idx, int):
            return self.poems[idx]
        elif isinstance(idx, str):
            return self._index_by_title.get(idx)
        elif isinstance(idx, slice):
            return self.poems[idx]
        else:
            raise TypeError("Индекс должен быть int, slice или str")

    def __iter__(self):
        return iter(self.poems)

    def __contains__(self, item):
        if isinstance(item, Poem):
            return item in self.poems
        elif isinstance(item, str):
            return item in self._index_by_title
        return False


    def save_to_json(self, filename):
        data = []
        for poem in self.poems:
            data.append({
                "title": poem.title,
                "lines": poem.lines,
                "url": poem.url,
            })

        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

        print(f"Коллекция сохранена в {filename}")

    def get_statistics(self):
        meters_count = Counter(p.meter for p in self.poems if p.meter)
        return {
            "total_poems": len(self),
            "total_lines": sum(len(p) for p in self.poems),
            "meters": dict(meters_count),
            "avg_lines_per_poem": sum(len(p) for p in self.poems) / len(self) if self.poems else 0
        }

# %%
class PoemFactory:

    @staticmethod
    def from_json(filepath):
        collection = PoemCollection()
        with open(filepath, 'r', encoding='utf-8') as f:
            data = json.load(f)
            for item in data:
                poem = Poem(
                    title=item.get('title', ''),
                    lines=item.get('lines', []),
                    url=item.get('url', ''),
                )
                collection.add_poem(poem)
        return collection

    @classmethod
    def from_urls(cls, urls, collector):
        collection = PoemCollection()
        for i, url in enumerate(urls, 1):
            print(f"[{i}/{len(urls)}] Загрузка {url}")
            try:
                poem = collector.fetch_poem(url)
                collection.add_poem(poem)
                time.sleep(0.3)  #вежливость
            except Exception as e:
                print(f"Ошибка при загрузке {url}: {e}")
        return collection

# %% [markdown]
# юниттесты

# %%
class TestLineToBitstring(unittest.TestCase):
    
    def setUp(self):
        self.analyzer = MetricalAnalyzer()

    def test_simple(self):
        self.assertEqual(self.analyzer._line_to_bitstring("промча`лся"), "010")
        self.assertEqual(self.analyzer._line_to_bitstring("промчался"), "000")
        self.assertEqual(self.analyzer._line_to_bitstring("ве`тер"), "10")

    def test_multiple(self):
        self.assertEqual(self.analyzer._line_to_bitstring("крова`вый ме`ч"), "0101")
        self.assertEqual(self.analyzer._line_to_bitstring("крова`вый ме`ч"), "0001") #ошибка
    
    def test_no_vowels(self):
        self.assertEqual(self.analyzer._line_to_bitstring("втр"), "")

# %%
if __name__ == '__main__':
    unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_multiple (__main__.TestLineToBitstring.test_multiple) ... FAIL
# test_no_vowels (__main__.TestLineToBitstring.test_no_vowels) ... ok
# test_simple (__main__.TestLineToBitstring.test_simple) ... ok
#
# ======================================================================
# FAIL: test_multiple (__main__.TestLineToBitstring.test_multiple)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "C:\Users\savch\AppData\Local\Temp\ipykernel_16596\3325843395.py", line 13, in test_multiple
#     self.assertEqual(self.analyzer._line_to_bitstring("крова`вый ме`ч"), "0001") #ошибка
#     ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: '0101' != '0001'
# - 0101
# ?  ^
# + 0001
# ?  ^
#
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.164s
#
# FAILED (failures=1)

# %%
def parse_pushkin_volume1():

    base_url = "https://rvb.ru/pushkin/"
    toc_url = "https://rvb.ru/pushkin/tocvol1.htm"
    output_file = "pushkin_vol1.json"

    collector = DataCollector(base_url)

    #список ссылок
    print("Получаю список стихотворений...")
    poem_links = get_poem_links(toc_url, collector)

    if not poem_links:
        print("Не найдено ссылок на стихотворения")
        return None

    print(f"Найдено ссылок: {len(poem_links)}")

    #через PoemFactory
    print("\nЗагружаю стихотворения...")
    collection = PoemFactory.from_urls(poem_links, collector)

    print(f"Успешно загружено: {len(collection)} стихотворений")

    print(f"\nСохраняю в {output_file}...")
    collection.save_to_json("output.json")

    print(f"Готово! Файл сохранён: {os.path.abspath(output_file)}")

    return collection

def get_poem_links(toc_url, collector):
    try:
        response = collector.session.get(toc_url, timeout=10)
        response.encoding = "windows-1251"
        soup = BeautifulSoup(response.text, "html5lib")

        poem_links = []
        for table in soup.find_all("table"):
            for a in table.find_all("a", href=True):
                href = a["href"]

                if any(x in href for x in ["articles", "comm", "index", "txtindex", "adresindex", "nameindex"]):
                    continue
                if href.startswith("http"):
                    continue

                full_url = urljoin(toc_url, href)
                poem_links.append(full_url)

        return poem_links

    except Exception as e:
        print(f"Ошибка при получении ссылок: {e}")
        return []

    with open(filename, "w", encoding="utf-8") as f:
        json.dump(all_poems, f, ensure_ascii=False, indent=2)

# %%
if __name__ == "__main__":
    collection = parse_pushkin_volume1()
# Out:
# Получаю список стихотворений...
# Найдено ссылок: 326
#
# Загружаю стихотворения...
# [1/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0001.htm
# [2/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0002.htm
# [3/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0003.htm
# Пустое: СТАРИК
# [4/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0004.htm
# Пустое: РОЗА
# [5/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0005.htm
# [6/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0006.htm
# [7/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0007.htm
# Пустое: К МОРФЕЮ
# [8/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0008.htm
# Пустое: ДРУЗЬЯМ
# [9/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0009.htm
# [10/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0010.htm
# [11/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0011.htm
# Пустое: ПРОБУЖДЕНИЕ
# [12/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0012.htm
# Пустое: ЛЮБОПЫТНЫЙ
# [13/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0013.htm
# Пустое: ДЕЛЬВИГУ
# [14/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0014.htm
# Пустое: К КАВЕРИНУ
# [15/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0015.htm
# Пустое: В. Л. ПУШКИНУ
# [16/326] Загрузка https://rvb.ru/pushkin/01text/01versus/01lyceum/0016.htm
# Пустое: РАЗЛУКА
# [17/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0017.htm
# Пустое: * * *
# [18/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0018.htm
# [19/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0019.htm
# [20/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0020.htm
# [21/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0021.htm
# Пустое: * * *
# [22/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0022.htm
# Пустое: К НЕЙ
# [23/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0023.htm
# [24/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0024.htm
# Пустое: КРИВЦОВУ
# [25/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1817pl/0025.htm
# Пустое: * * *
# [26/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0026.htm
# [27/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0027.htm
# Пустое: КН. ГОЛИЦЫНОЙ,ПОСЫЛАЯ ЕЙ ОДУ «ВОЛЬНОСТЬ»
# [28/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0028.htm
# Пустое: * * *
# [29/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0029.htm
# [30/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0030.htm
# Пустое: ЖУКОВСКОМУ
# [31/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0031.htm
# Пустое: К ПОРТРЕТУ ЖУКОВСКОГО
# [32/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0032.htm
# Пустое: МЕЧТАТЕЛЮ
# [33/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0033.htm
# Пустое: КН. Я. ПЛЮСКОВОЙ
# [34/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0034.htm
# [35/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0035.htm
# [36/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0036.htm
# Пустое: КЧААДАЕВУ
# [37/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0037.htm
# Пустое: НА КАРАМЗИНА
# [38/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0038.htm
# Пустое: НА КАЧЕНОВСКОГО
# [39/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0039.htm
# Пустое: * * *
# [40/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1818/0040.htm
# Пустое: ИСТОРИЯ СТИХОТВОРЦА
# [41/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0041.htm
# Пустое: О. МАССОН
# [42/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0042.htm
# Пустое: ДОРИДА
# [43/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0043.htm
# [44/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0044.htm
# [45/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0045.htm
# [46/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0046.htm
# [47/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0047.htm
# Пустое: ДОМОВОМУ
# [48/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0048.htm
# [49/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0049.htm
# [50/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0050.htm
# Пустое: УЕДИНЕНИЕ
# [51/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0051.htm
# Пустое: ВЕСЕЛЫЙ ПИР
# [52/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0052.htm
# Пустое: ЛИЛЕ
# [53/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0053.htm
# [54/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0054.htm
# [55/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0055.htm
# [56/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0056.htm
# [57/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0057.htm
# [58/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0058.htm
# Пустое: ДОБРЫЙ ЧЕЛОВЕК
# [59/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0059.htm
# Пустое: К ПОРТРЕТУ ДЕЛЬВИГА
# [60/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0060.htm
# Пустое: НАСТУРДЗУ
# [61/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0061.htm
# Пустое: МАДРИГАЛ М....ОЙ
# [62/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0062.htm
# Пустое: ИМЕНИНЫ
# [63/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0063.htm
# Пустое: К. А. Б***
# [64/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0064.htm
# Пустое: В АЛЬБОМСОСНИЦКОЙ
# [65/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0065.htm
# Пустое: БАКУНИНОЙ
# [66/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0066.htm
# Пустое: НА КОЛОСОВУ
# [67/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0067.htm
# Пустое: ЗАПИСКА К ЖУКОВСКОМУ
# [68/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1819/0068.htm
# Пустое: * * *
# [69/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0069.htm
# Пустое: ДОРИДЕ
# [70/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0070.htm
# Пустое: * * *
# [71/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0071.htm
# Пустое: ТЫ И Я
# [72/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0072.htm
# Пустое: ДОБРЫЙ СОВЕТ
# [73/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0073.htm
# [74/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0074.htm
# Пустое: * * *
# [75/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0075.htm
# Пустое: К***
# [76/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0076.htm
# [77/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0077.htm
# Пустое: * * *
# [78/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0078.htm
# Пустое: ДОЧЕРИКАРАГЕОРГИЯ
# [79/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0079.htm
# [80/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0080.htm
# Пустое: НЕРЕИДА
# [81/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0081.htm
# Пустое: * * *
# [82/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0082.htm
# Пустое: К ПОРТРЕТУ ЧААДАЕВА
# [83/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0083.htm
# Пустое: К ПОРТРЕТУ ВЯЗЕМСКОГО
# [84/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0084.htm
# Пустое: НА АРАКЧЕЕВА
# [85/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0085.htm
# Пустое: ЗАПИСКА К ЖУКОВСКОМУ
# [86/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0086.htm
# Пустое: * * *
# [87/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0087.htm
# Пустое: * * *
# [88/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0088.htm
# Пустое: НА КАЧЕНОВСКОГО
# [89/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0089.htm
# Пустое: * * *
# [90/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1820/0090.htm
# Пустое: ЭПИГРАММА(НАГР. Ф. И. ТОЛСТОГО)
# [91/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0091.htm
# Пустое: ЗЕМЛЯ И МОРЕ
# [92/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0092.htm
# Пустое: КРАСАВИЦА ПЕРЕД ЗЕРКАЛОМ
# [93/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0093.htm
# Пустое: МУЗА
# [94/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0094.htm
# [95/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0095.htm
# [96/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0096.htm
# Пустое: ДЕЛЬВИГУ
# [97/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0097.htm
# [98/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0098.htm
# [99/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0099.htm
# [100/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0100.htm
# Пустое: ДЕВА
# [101/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0101.htm
# Пустое: КАТЕНИНУ
# [102/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0102.htm
# [103/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0103.htm
# [104/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0104.htm
# Пустое: ДИОНЕЯ
# [105/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0105.htm
# Пустое: * * *
# [106/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0106.htm
# Пустое: ГЕНЕРАЛУ ПУЩИНУ
# [107/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0107.htm
# Пустое: * * *
# [108/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0108.htm
# Пустое: * * *
# [109/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0109.htm
# [110/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0110.htm
# [111/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0111.htm
# Пустое: * * *
# [112/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0112.htm
# [113/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0113.htm
# Пустое: ПРИМЕТЫ
# [114/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0114.htm
# [115/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0115.htm
# Пустое: ПРИЯТЕЛЮ
# [116/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0116.htm
# [117/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0117.htm
# Пустое: * * *
# [118/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0118.htm
# Пустое: ДЕСЯТАЯ ЗАПОВЕДЬ
# [119/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0119.htm
# Пустое: * * *
# [120/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0120.htm
# Пустое: ХРИСТОС ВОСКРЕС
# [121/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0121.htm
# Пустое: * * *
# [122/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0122.htm
# Пустое: ЭПИГРАММА
# [123/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0123.htm
# Пустое: * * *
# [124/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1821/0124.htm
# Пустое: НА КАЧЕНОВСКОГО
# [125/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0125.htm
# Пустое: БАРАТЫНСКОМУИЗ БЕССАРАБИИ
# [126/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0126.htm
# [127/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0127.htm
# [128/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0128.htm
# [129/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0129.htm
# [130/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0130.htm
# [131/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0131.htm
# [132/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0132.htm
# Пустое: ИНОСТРАНКЕ
# [133/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0133.htm
# Пустое: * * *
# [134/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0134.htm
# Пустое: Ф. Н. ГЛИНКЕ
# [135/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0135.htm
# [136/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0136.htm
# Пустое: АДЕЛИ
# [137/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0137.htm
# [138/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0138.htm
# Пустое: БАРАТЫНСКОМУ
# [139/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0139.htm
# Пустое: НА А. А. ДАВЫДОВУ
# [140/326] Загрузка https://rvb.ru/pushkin/01text/01versus/0217_22/1822/0140.htm
# Пустое: * * *
# [141/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1813/0141.htm
# [142/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1813/0142.htm
# Пустое: НЕСЧАСТИЕ КЛИТА
# [143/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1813/0143.htm
# Пустое: ДВУМ АЛЕКСАНДРАМ ПАВЛОВИЧАМ
# [144/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0144.htm
# [145/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0145.htm
# [146/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0146.htm
# [147/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0147.htm
# [148/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0148.htm
# [149/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0149.htm
# [150/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0150.htm
# [151/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0151.htm
# Пустое: ЭПИГРАММА
# [152/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0152.htm
# [153/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0153.htm
# [154/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0154.htm
# [155/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0155.htm
# [156/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0156.htm
# Пустое: ЛАИСА ВЕНЕРЕ,ПОСВЯЩАЯ ЕЙ СВОЕ ЗЕРКАЛО
# [157/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0157.htm
# [158/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0158.htm
# [159/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0159.htm
# [160/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0160.htm
# Пустое: ЭПИГРАММА(ПОДРАЖАНИЕ ФРАНЦУЗСКОМУ).
# [161/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0161.htm
# Пустое: К Н. Г. ЛОМОНОСОВУ
# [162/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0162.htm
# Пустое: НА РЫБУШКИНА
# [163/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0163.htm
# [164/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0164.htm
# [165/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0165.htm
# [166/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0166.htm
# [167/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0167.htm
# Пустое: НА ПУЧКОВУ
# [168/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0168.htm
# [169/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1814/0169.htm
# [170/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0170.htm
# [171/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0171.htm
# [172/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0172.htm
# [173/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0173.htm
# [174/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0174.htm
# [175/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0175.htm
# Пустое: К ПУЩИНУ(4 МАЯ)
# [176/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0176.htm
# Пустое: К ГАЛИЧУ
# [177/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0177.htm
# [178/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0178.htm
# [179/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0179.htm
# [180/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0180.htm
# Пустое: К МОЛОДОЙ АКТРИСЕ
# [181/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0181.htm
# [182/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0182.htm
# [183/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0183.htm
# Пустое: МОЯ ЭПИТАФИЯ
# [184/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0184.htm
# [185/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0185.htm
# [186/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0186.htm
# [187/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0187.htm
# Пустое: * * *
# [188/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0188.htm
# [189/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0189.htm
# Пустое: * * *
# [190/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0190.htm
# Пустое: К бар. М. А. ДЕЛЬВИГ
# [191/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0191.htm
# [192/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0192.htm
# [193/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0193.htm
# [194/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0194.htm
# [195/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0195.htm
# Пустое: * * *
# [196/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1815/0196.htm
# [197/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0197.htm
# [198/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0198.htm
# Пустое: * * *
# [199/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0199.htm
# [200/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0200.htm
# Пустое: ИЗ ПИСЬМАК кн. П. А. ВЯЗЕМСКОМУ
# [201/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0201.htm
# Пустое: ИЗ ПИСЬМАК В. Л. ПУШКИНУ
# [202/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0202.htm
# [203/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0203.htm
# [204/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0204.htm
# Пустое: Кж. В. М. ВОЛКОНСКОЙ
# [205/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0205.htm
# Пустое: ЭКСПРОМПТ НА ОГАРЕВУ
# [206/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0206.htm
# [207/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0207.htm
# [208/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0208.htm
# Пустое: ОСЕННЕЕ УТРО
# [209/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0209.htm
# [210/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0210.htm
# [211/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0211.htm
# Пустое: НА ПУЧКОВУ
# [212/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0212.htm
# Пустое: ДЯДЕ, НАЗВАВШЕМУ СОЧИНИТЕЛЯ БРАТОМ
# [213/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0213.htm
# [214/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0214.htm
# Пустое: ЭЛЕГИЯ
# [215/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0215.htm
# Пустое: МЕСЯЦ
# [216/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0216.htm
# Пустое: СЛОВО МИЛОЙ
# [217/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0217.htm
# [218/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0218.htm
# [219/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0219.htm
# Пустое: ЖЕЛАНИЕ
# [220/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0220.htm
# [221/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0221.htm
# [222/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0222.htm
# [223/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0223.htm
# Пустое: ПОСЛАНИЕЛИДЕ
# [224/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0224.htm
# Пустое: ФИАЛ АНАКРЕОНА
# [225/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0225.htm
# [226/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0226.htm
# [227/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0227.htm
# Пустое: * * *
# [228/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0228.htm
# Пустое: НАДПИСЬ К БЕСЕДКЕ
# [229/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0229.htm
# Пустое: * * *
# [230/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0230.htm
# Пустое: НА гр. А. К.РАЗУМОВСКОГО
# [231/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0231.htm
# Пустое: НА БАБОЛОВСКИЙ ДВОРЕЦ
# [232/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0232.htm
# Пустое: ТВОЙ И МОЙ
# [233/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0233.htm
# [234/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0234.htm
# Пустое: * * *
# [235/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0235.htm
# [236/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0236.htm
# Пустое: СРАВНЕНИЕ
# [237/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0237.htm
# Пустое: ЭПИГРАММА(НА КАРАМЗИНА)
# [238/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0238.htm
# Пустое: ЗАВЕЩАНИЕ КЮХЕЛЬБЕКЕРА
# [239/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0239.htm
# [240/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1816/0240.htm
# [241/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0241.htm
# [242/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0242.htm
# Пустое: К МОЛОДОЙ ВДОВЕ
# [243/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0243.htm
# [244/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0244.htm
# [245/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0245.htm
# Пустое: ПИСЬМО К ЛИДЕ
# [246/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0246.htm
# [247/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0247.htm
# Пустое: В АЛЬБОМ
# [248/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0248.htm
# Пустое: В АЛЬБОМИЛЛИЧЕВСКОМУ
# [249/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0249.htm
# [250/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0250.htm
# Пустое: НАДПИСЬ НА СТЕНЕ БОЛЬНИЦЫ
# [251/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0251.htm
# Пустое: В АЛЬБОМПУЩИНУ
# [252/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0252.htm
# Пустое: К ПОРТРЕТУКАВЕРИНА
# [253/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0253.htm
# Пустое: К ПИСЬМУ
# [254/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0254.htm
# Пустое: СНОВИДЕНИЕ
# [255/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0255.htm
# Пустое: ОНА
# [256/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0256.htm
# Пустое: * * *
# [257/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0257.htm
# Пустое: * * *
# [258/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0258.htm
# Пустое: ЭПИГРАММАНА СМЕРТЬ СТИХОТВОРЦА
# [259/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0259.htm
# Пустое: ПОРТРЕТ
# [260/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0260.htm
# Пустое: * * *
# [261/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0261.htm
# [262/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817l/0262.htm
# Пустое: * * *
# [263/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817pl/0263.htm
# [264/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817pl/0264.htm
# [265/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817pl/0265.htm
# Пустое: * * *
# [266/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1817pl/0266.htm
# Пустое: КН. П. А. ВЯЗЕМСКОМУ
# [267/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1818/0267.htm
# [268/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1818/0268.htm
# Пустое: * * *
# [269/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1818/0269.htm
# Пустое: К ***
# [270/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1818/0270.htm
# Пустое: * * *
# [271/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1818/0271.htm
# Пустое: * * *
# [272/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1818/0272.htm
# Пустое: КОЛОСОВОЙ
# [273/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0273.htm
# Пустое: * * *
# [274/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0274.htm
# Пустое: * * *
# [275/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0275.htm
# Пустое: * * *
# [276/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0276.htm
# Пустое: ПОСЛАНИЕ К А. И. ТУРГЕНЕВУ
# [277/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0277.htm
# Пустое: ЭЛЕГИЯ
# [278/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0278.htm
# Пустое: 27 МАЯ 1819
# [279/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0279.htm
# [280/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0280.htm
# Пустое: * * *
# [281/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0281.htm
# Пустое: * * *
# [282/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0282.htm
# Пустое: НА СТУРДЗУ
# [283/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0283.htm
# [284/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0284.htm
# Пустое: ДЕНИСУ ДАВЫДОВУ
# [285/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0285.htm
# Пустое: * * *
# [286/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0286.htm
# [287/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0287.htm
# [288/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0288.htm
# Пустое: * * *
# [289/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0289.htm
# Пустое: * * *
# [290/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0290.htm
# Пустое: * * *
# [291/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0291.htm
# [292/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0292.htm
# Пустое: НА АРАКЧЕЕВА
# [293/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1819/0293.htm
# Пустое: * * *
# [294/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1820/0294.htm
# Пустое: НИМФОДОРЕ СЕМЕНОВОЙ
# [295/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1820/0295.htm
# Пустое: * * *
# [296/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1820/0296.htm
# Пустое: ПРО СЕБЯ
# [297/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0297.htm
# Пустое: * * *
# [298/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0298.htm
# Пустое: * * *
# [299/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0299.htm
# Пустое: * * *
# [300/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0300.htm
# Пустое: * * *
# [301/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0301.htm
# [302/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0302.htm
# [303/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0303.htm
# [304/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0304.htm
# Пустое: ВЯЗЕМСКОМУ
# [305/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0305.htm
# [306/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0306.htm
# Пустое: * * *
# [307/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0307.htm
# Пустое: * * *
# [308/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0308.htm
# Пустое: * * *
# [309/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0309.htm
# [310/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0310.htm
# [311/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0311.htm
# Пустое: * * *
# [312/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0312.htm
# Пустое: * * *
# [313/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0313.htm
# Пустое: ИЗ БАЙРОНА
# [314/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0314.htm
# Пустое: * * *
# [315/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0315.htm
# Пустое: * * *
# [316/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1821/0316.htm
# Пустое: ЭПИГРАММА(НА А. А. ДАВЫДОВУ)
# [317/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0317.htm
# Пустое: * * *
# [318/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0318.htm
# [319/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0319.htm
# Пустое: ТАВРИДА.
# [320/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0320.htm
# Пустое: * * *
# [321/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0321.htm
# Пустое: В. Ф. РАЕВСКОМУ
# [322/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0322.htm
# [323/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0323.htm
# [324/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0324.htm
# Пустое: * * *
# [325/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0325.htm
# Пустое: НАЛАНОВА
# [326/326] Загрузка https://rvb.ru/pushkin/01text/01versus/03juv_misc/1822/0326.htm
# Пустое: * * *
# Успешно загружено: 131 стихотворений
#
# Сохраняю в pushkin_vol1.json...
# Коллекция сохранена в output.json
# Готово! Файл сохранён: C:\Users\savch\OOP\project\pushkin_vol1.json

# %% [markdown]
# словарь ударений

# %%
# исправленое!!
def parse_par_file(filepath):
    emphasis_dict = defaultdict(lambda: defaultdict(set))

    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue

            #НЕБО1
            if re.match(r'^[А-ЯЁ0-9$]+$', line):
                continue

            #не`бо - S,ЕД,...
            if '-' not in line:
                continue

            parts = line.split('-', 1)
            emphasised_form = parts[0].strip()
            pos_info = parts[1].strip()

            pos = pos_info.split(',')[0]  #метка POS

            #ударения, ё - е, нижний регистр
            lemma_like = re.sub(r'[`\~]', '', emphasised_form).lower()
            lemma_like = lemma_like.replace('ё', 'е')

            #форма с ударением в нижнем регистре
            emphasised_form_lower = emphasised_form.lower()

            emphasis_dict[lemma_like][pos].add(emphasised_form_lower)

    #в dict
    return {word: {pos: forms for pos, forms in pos_dict.items()}
            for word, pos_dict in emphasis_dict.items()}

# %%
def save_dict_to_pkl_gz(data, output_path):
    with gzip.open(output_path, 'wb') as f:
        pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
def load_emphasis_dict(path="emphasis_dict.pkl.gz"):
    with gzip.open(path, "rb") as f:
        return pickle.load(f)

# %%
if __name__ == "__main__":
    input_file = "par.txt"
    output_file = "emphasis_dict.pkl.gz"

    print("Парсинг файла...")
    emphasis_dict = parse_par_file(input_file)

    save_dict_to_pkl_gz(emphasis_dict, output_file)
    print(f"Словарь сохранён в {output_file}")
# Out:
# Парсинг файла...
# Словарь сохранён в emphasis_dict.pkl.gz

# %% [markdown]
# Словарь ё

# %%
class Yoficator:
    def __init__(self, dict_path="yo_dict.pkl.gz"):
        #словарь из .pkl.gz файла.

        with gzip.open(dict_path, 'rb') as f:
            self.yo_dict = pickle.load(f)
        print(f"Ёфикатор загружен: {len(self.yo_dict):,} слов.")

    def _restore_case(self, original: str, replacement: str) -> str: #регистр

        if original.isupper():
            return replacement.upper()
        elif original.istitle():
            return replacement.capitalize()
        else:
            return replacement

    def yoficate_word(self, word: str) -> str:
        lower_word = word.lower()
        if lower_word in self.yo_dict:
            corrected = self.yo_dict[lower_word]
            return self._restore_case(word, corrected)
        return word

# %%
def build_yo_normalization_dict(par_file_path):

    #словарь замены слов с 'е' на 'ё' на основе par.txt. без (` и ~)

    yo_dict = {}

    with open(par_file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    for line in lines:
        line = line.strip()
        if not line or '$' in line:
            continue

        match = re.match(r'^(.+?)\s*-\s*[A-Z]+', line)
        if not match:
            continue

        emphasised_form = match.group(1).strip()

        #` и ~
        clean_form = emphasised_form.replace('`', '').replace('~', '')

        clean_lower = clean_form.lower()

        if 'ё' not in clean_lower:
            continue

        variant_with_e = clean_lower.replace('ё', 'е')

        if variant_with_e != clean_lower:
            yo_dict[variant_with_e] = clean_lower

    return yo_dict

# %%
def save_yo_dict(yo_dict, output_path):
    with gzip.open(output_path, 'wb') as f:
        pickle.dump(yo_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

def load_yo_dict(path):
    with gzip.open(path, 'rb') as f:
        return pickle.load(f)

# %%
if __name__ == "__main__":
    par_file = "par.txt"
    output_file = "yo_dict.pkl.gz"

    print("Строим словарь из par.txt...")
    yo_dict = build_yo_normalization_dict(par_file)

    print(f"Словарь содержит {len(yo_dict):,} пар.\n")

    save_yo_dict(yo_dict, output_file)
    print(f"\nСловарь сохранён в {output_file}")
# Out:
# Строим словарь из par.txt...
# Словарь содержит 121,796 пар.
#
#
# Словарь сохранён в yo_dict.pkl.gz

# %% [markdown]
# Обработка

# %%
yoficator = Yoficator("yo_dict.pkl.gz")
# Out:
# Ёфикатор загружен: 121,796 слов.

# %%
def add_emphasis_to_word(word, emphasis_dict, yoficator):
    yo_word = yoficator.yoficate_word(word)

    #нормализую: ё - е (если в словаре ключи с "е")
    search_key = yo_word.lower().replace('ё', 'е')

    if search_key in emphasis_dict:
        #берем первую форму с ударением
        for pos_forms in emphasis_dict[search_key].values():
            for emphasised_form in pos_forms:
                #восстанавливаю регистр
                if word.isupper():
                    return emphasised_form.upper()
                elif word.istitle():
                    return emphasised_form.capitalize()
                else:
                    return emphasised_form

    return yo_word

def emphasize_text(text, emphasis_dict, yoficator):
    def process_match(match):
        word = match.group(0)
        return add_emphasis_to_word(word, emphasis_dict, yoficator)

    return re.sub(r'[А-Яа-яЁё]+', process_match, text)

# %%
processed_poems = []
with open('pushkin_vol1.json', 'r', encoding='utf-8') as f:
    all_poems = json.load(f)

for i, poem in enumerate(all_poems):
    print(f"Обработка [{i+1}/{len(all_poems)}]: {poem['title'][:50]}...")

    processed_lines = []
    for line in poem['lines']:
        if line.strip():
            processed_line = emphasize_text(line, emphasis_dict, yoficator)
            processed_lines.append(processed_line)
        else:
            processed_lines.append("")

    processed_poems.append({
        "title": poem['title'],
        "lines": processed_lines,
        "url": poem['url']
    })
processed_output_file = "pushkin_vol1_processed.json"
with open(processed_output_file, 'w', encoding='utf-8') as f:
    json.dump(processed_poems, f, ensure_ascii=False, indent=2)

print(f"Сохранено в {processed_output_file}")
# Out:
# Обработка [1/131]: ВОСПОМИНАНИЯ В ЦАРСКОМ СЕЛЕ...
# Обработка [2/131]: ЛИЦИНИЮ...
# Обработка [3/131]: ГРОБ АНАКРЕОНА...
# Обработка [4/131]: ПЕВЕЦ...
# Обработка [5/131]: АМУР И ГИМЕНЕЙ...
# Обработка [6/131]: ШИШКОВУ...
# Обработка [7/131]: К ОГАРЕВОЙ,КОТОРОЙ МИТРОПОЛИТ ПРИСЛАЛ ПЛОДОВ ИЗ СВ...
# Обработка [8/131]: ТУРГЕНЕВУ...
# Обработка [9/131]: К ***...
# Обработка [10/131]: ВОЛЬНОСТЬОДА...
# Обработка [11/131]: ТОРЖЕСТВО ВАКХА...
# Обработка [12/131]: ВЫЗДОРОВЛЕНИЕ...
# Обработка [13/131]: СКАЗКИNOËL...
# Обработка [14/131]: ПРЕЛЕСТНИЦЕ...
# Обработка [15/131]: N. N....
# Обработка [16/131]: ОРЛОВУ...
# Обработка [17/131]: КЩЕРБИНИНУ...
# Обработка [18/131]: ДЕРЕВНЯ...
# Обработка [19/131]: РУСАЛКА...
# Обработка [20/131]: НЕДОКОНЧЕННАЯ КАРТИНА...
# Обработка [21/131]: ВСЕВОЛОЖСКОМУ...
# Обработка [22/131]: ПЛАТОНИЗМ...
# Обработка [23/131]: СТАНСЫТОЛСТОМУ...
# Обработка [24/131]: ВОЗРОЖДЕНИЕ...
# Обработка [25/131]: ПОСЛАНИЕ К кн.ГОРЧАКОВУ...
# Обработка [26/131]: ЮРЬЕВУ...
# Обработка [27/131]: * * *...
# Обработка [28/131]: ЧЕРНАЯ ШАЛЬ...
# Обработка [29/131]: * * *...
# Обработка [30/131]: ВОЙНА...
# Обработка [31/131]: ИЗ ПИСЬМА К ГНЕДИЧУ...
# Обработка [32/131]: КИНЖАЛ...
# Обработка [33/131]: В. Л. ДАВЫДОВУ...
# Обработка [34/131]: ЧААДАЕВУ...
# Обработка [35/131]: * * *...
# Обработка [36/131]: ГРОБ ЮНОШИ...
# Обработка [37/131]: НАПОЛЕОН...
# Обработка [38/131]: К ОВИДИЮ...
# Обработка [39/131]: КОКЕТКЕ...
# Обработка [40/131]: АЛЕКСЕЕВУ...
# Обработка [41/131]: ДРУЗЬЯМ...
# Обработка [42/131]: Песнь о вещем Олеге...
# Обработка [43/131]: * * *...
# Обработка [44/131]: ГРЕЧАНКЕ...
# Обработка [45/131]: ИЗ ПИСЬМА К Я. Н. ТОЛСТОМУ...
# Обработка [46/131]: ПОСЛАНИЕ ЦЕНЗОРУ...
# Обработка [47/131]: * * *...
# Обработка [48/131]: УЗНИК...
# Обработка [49/131]: К НАТАЛЬЕ...
# Обработка [50/131]: К ДРУГУ СТИХОТВОРЦУ...
# Обработка [51/131]: КОЛЬНА.(ПОДРАЖАНИЕОССИАНУ)....
# Обработка [52/131]: ЭВЛЕГА...
# Обработка [53/131]: ОСГАР...
# Обработка [54/131]: РАССУДОК И ЛЮБОВЬ...
# Обработка [55/131]: К СЕСТРЕ...
# Обработка [56/131]: КРАСАВИЦЕ, КОТОРАЯ НЮХАЛА ТАБАК...
# Обработка [57/131]: КАЗАК...
# Обработка [58/131]: КНЯЗЮ А. М. ГОРЧАКОВУ...
# Обработка [59/131]: ОПЫТНОСТЬ...
# Обработка [60/131]: БЛАЖЕНСТВО...
# Обработка [61/131]: К НАТАШЕ...
# Обработка [62/131]: К СТУДЕНТАМ...
# Обработка [63/131]: К БАТЮШКОВУ...
# Обработка [64/131]: РОМАНС...
# Обработка [65/131]: ЛЕДА(КАНТАТА)...
# Обработка [66/131]: STANCES...
# Обработка [67/131]: MON PORTRAIT...
# Обработка [68/131]: ГАРАЛЬ И ГАЛЬВИНА...
# Обработка [69/131]: ИСПОВЕДЬ БЕДНОГО СТИХОТВОРЦА...
# Обработка [70/131]: ГОРОДОК(К ***)...
# Обработка [71/131]: ВОДА И ВИНО...
# Обработка [72/131]: ИЗМЕНЫ...
# Обработка [73/131]: БАТЮШКОВУ...
# Обработка [74/131]: НАПОЛЕОН НА ЭЛЬБЕ (1815)...
# Обработка [75/131]: МЕЧТАТЕЛЬ...
# Обработка [76/131]: МОЕ ЗАВЕЩАНИЕ.ДРУЗЬЯМ...
# Обработка [77/131]: К НЕЙ...
# Обработка [78/131]: ВОСПОМИНАНИЕ(К ПУЩИНУ)...
# Обработка [79/131]: ПОСЛАНИЕ К ГАЛИЧУ...
# Обработка [80/131]: СРАЖЕННЫЙ РЫЦАРЬ...
# Обработка [81/131]: К ДЕЛЬВИГУ(ОТВЕТ)...
# Обработка [82/131]: НА ВОЗВРАЩЕНИЕГОСУДАРЯ ИМПЕРАТОРАИЗ ПАРИЖА В 1815 ...
# Обработка [83/131]: СЛЕЗА...
# Обработка [84/131]: МОЕМУ АРИСТАРХУ...
# Обработка [85/131]: ТЕНЬ ФОНВИЗИНА...
# Обработка [86/131]: ПОСЛАНИЕ КЮДИНУ...
# Обработка [87/131]: К ЖИВОПИСЦУ...
# Обработка [88/131]: ВИШНЯ...
# Обработка [89/131]: К МАШЕ...
# Обработка [90/131]: УСЫФИЛОСОФИЧЕСКАЯ ОДА...
# Обработка [91/131]: ПРИНЦУ ОРАНСКОМУ...
# Обработка [92/131]: СОН(ОТРЫВОК)...
# Обработка [93/131]: ОКНО...
# Обработка [94/131]: К ЖУКОВСКОМУ...
# Обработка [95/131]: УНЫНИЕ...
# Обработка [96/131]: ИСТИНА...
# Обработка [97/131]: НАЕЗДНИКИ...
# Обработка [98/131]: * * *...
# Обработка [99/131]: ПОДРАЖАНИЕ...
# Обработка [100/131]: ЭЛЕГИЯ...
# Обработка [101/131]: НАСЛАЖДЕНЬЕ...
# Обработка [102/131]: ЗАЗДРАВНЫЙ КУБОК...
# Обработка [103/131]: ДЕЛИЯ...
# Обработка [104/131]: ФАВН И ПАСТУШКАКАРТИНЫ...
# Обработка [105/131]: К ДЕЛИИ...
# Обработка [106/131]: ПОГРЕБ...
# Обработка [107/131]: КУПЛЕТЫ(НА СЛОВА «С ПОЗВОЛЕНИЯ СКАЗАТЬ»)...
# Обработка [108/131]: * * *...
# Обработка [109/131]: ЭЛЕГИЯ...
# Обработка [110/131]: БЕЗВЕРИЕ...
# Обработка [111/131]: СТАНСЫ(ИЗ ВОЛЬТЕРА)...
# Обработка [112/131]: КНЯЗЮ А. М. ГОРЧАКОВУ...
# Обработка [113/131]: ПРОЩАНЬЕ...
# Обработка [114/131]: COUPLETS...
# Обработка [115/131]: * * *...
# Обработка [116/131]: * * *...
# Обработка [117/131]: * * *...
# Обработка [118/131]: МАНСУРОВУ...
# Обработка [119/131]: ЮРЬЕВУ...
# Обработка [120/131]: * * *...
# Обработка [121/131]: * * *...
# Обработка [122/131]: БАЛЛАДА...
# Обработка [123/131]: К МОЕЙ ЧЕРНИЛЬНИЦЕ...
# Обработка [124/131]: * * *...
# Обработка [125/131]: * * *...
# Обработка [126/131]: * * *...
# Обработка [127/131]: ДЕНИСУ ДАВЫДОВУ...
# Обработка [128/131]: МОЛДАВСКАЯ ПЕСНЯ...
# Обработка [129/131]: * * *...
# Обработка [130/131]: В. Ф. РАЕВСКОМУ...
# Обработка [131/131]: В. Ф. РАЕВСКОМУ...
# Сохранено в pushkin_vol1_processed.json

# %%
def main():
    setup_logging()
    logger = logging.getLogger(__name__)
    
    logger.info("Автоматическое определение стихотворного метра")
    
    try:
        factory = PoemFactory()
        collection = factory.from_json(processed_output_file)
        logger.info(f"Загружено {len(collection)} стихотворений")
        
        analyzer = MetricalAnalyzer()
        
        results = []
        
        for i, poem in enumerate(collection, 1):
            logger.info(f"[{i}/{len(collection)}] Анализируем: {poem.title}")
            result = analyzer.process(poem)
            logger.debug(f"Результат: {result}")
            
            results.append({
                "title": poem.title,
                "meter": result.get("meter", "неопределен"),
                "confidence": round(result.get("confidence", 0.0), 4),
                "url": poem.url,
                "line_count": len(poem)
            })
        stats = collection.get_statistics()
        logger.info(f"Статистика: {stats}")

        print(f"Всего стихотворений: {stats['total_poems']}")
        print(f"Всего строк: {stats['total_lines']}")
        print(f"Среднее строк на стихотворение: {stats['avg_lines_per_poem']:.1f}")
        print("\nРаспределение метров:")
        
        for meter, count in stats['meters'].items():
            percentage = (count / stats['total_poems']) * 100
            print(f"  {meter}: {count} ({percentage:.1f}%)")

        results_file = "results.json"
        with open(results_file, 'w', encoding='utf-8') as f:
            json.dump({
                "metadata": {
                    "analysis_date": time.strftime("%Y-%m-%d %H:%M:%S"),
                    "total_poems": len(collection),
                    "total_lines": stats["total_lines"]
                },
                "statistics": stats,
                "detailed_results": results
            }, f, ensure_ascii=False, indent=2, default=str)

        logger.info(f"Результаты сохранены в {results_file}")
        
    except Exception as e:
        logger.critical(f"Критическая ошибка в main(): {e}", exc_info=True)
        raise
    
    logger.info("Завершено успешно")
    logging.shutdown()

# %%
if __name__ == "__main__":
    main()
# Out:
# Всего стихотворений: 131
# Всего строк: 4139
# Среднее строк на стихотворение: 31.6
#
# Распределение метров:
#   ямб: 106 (80.9%)
#   хорей: 11 (8.4%)
#   смешанный: 11 (8.4%)
#   неопределен: 3 (2.3%)

# %% [markdown]
# Переделано под критерии:
#
# 1. Использование классов.
#  Poem, VerseProcessor, MetricalAnalyzer, DataCollector, PoemCollection, PoemFactory, Yoficator
# 2. Использование наследования от какого-нибудь класса.
#  MetricalAnalyzer наследуется от VerseProcessor
# 3. Использование наследования от созданного своими руками класса.
#  MetricalAnalyzer наследуется от VerseProcessor
# 4. Использование абстрактных классов в структуре классов.
# VerseProcessor
# 5. Три библиотеки из тех, что приходится ставить своими руками.
# pymorphy3, beautifulsoup4, requests
# 6. Использование декораторов.
# @abstractmethod, @log_processing, @wraps
# 7. Использование собственного декоратора.
# @log_processing
# 8. Перегрузка операторов.
# в PoemCollection
# 10. Использование каких-либо исключений.
# PoemAnalysisError, EmptyPoemError, DataFetchError
# 11. Использование исключений своего собственного типа.
# PoemAnalysisError, EmptyPoemError, DataFetchError
